# %%
import os
import pandas as pd
from bertopic import BERTopic
from src import preprocess_data, extract_date_days, generate_topic_labels, save_result_topics

# %% [markdown]
# # International news

# %% [markdown]
# Read data

# %%
file_path = os.path.join("..", "data.xlsx")

data = pd.read_excel(io = file_path,
                     sheet_name = "Міжнародні")

# %% [markdown]
# **Analyze data**

# %%
data.head()
# Out:
#                   Дата            Джерело  \
# 0  2025-02-13 13:07:18            Reuters
# 1  2025-02-13 13:09:45  The Straits Times
# 2  2025-02-13 13:06:39                AOL
# 3  2025-02-15 17:09:24               NDTV
# 4  2025-02-09 11:21:49               NDTV
#
#                                            Заголовок  \
# 0  "50% battle-ready": Germany misses military ta...
# 1  "50% battle-ready": Germany misses military ta...
# 2  "50% battle-ready": Germany misses military ta...
# 3  "Armed Forces Of Europe Must Be Created": Zele...
# 4  "Can't Confirm Or Deny": Kremlin On Reports Of...
#
#                                                 Опис  \
# 0  The German army's battle-readiness is less tha...
# 1  BERLIN - The German army's battle-readiness is...
# 2  The German army's battle-readiness is less tha...
# 3  Ukrainian President Volodymyr Zelensky called ...
# 4  The Kremlin on Sunday declined to confirm or d...
#
#                                            Посилання                 Автор  \
# 0  https://www.reuters.com/world/europe/50-battle...        Sabine Siebold
# 1  https://www.straitstimes.com/world/europe/50-b...                   NaN
# 2  https://www.aol.com/news/50-battle-ready-germa...        Sabine Siebold
# 3  https://www.ndtv.com/world-news/armed-forces-o...  Agence France-Presse
# 4  https://www.ndtv.com/world-news/cant-confirm-o...  Agence France-Presse
#
#    Популярність джерела Мова Країна
# 0                   101   en     GB
# 1                  1187   en     SG
# 2                   295   en     US
# 3                   841   en     IN
# 4                   841   en     IN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9346 entries, 0 to 9345
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Дата                  9346 non-null   object
#  1   Джерело               9339 non-null   object
#  2   Заголовок             9346 non-null   object
#  3   Опис                  7614 non-null   object
#  4   Посилання             9346 non-null   object
#  5   Автор                 8170 non-null   object
#  6   Популярність джерела  9346 non-null   int64
#  7   Мова                  9346 non-null   object
#  8   Країна                9346 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 657.3+ KB

# %% [markdown]
# We have some news without any description, but all news contain the header.

# %%
data["Мова"].value_counts()
# Out:
# Мова
# en    9346
# Name: count, dtype: int64

# %% [markdown]
# All international news are in English. So we can use BERTopic specified on English to achieve better results.

# %% [markdown]
# # Train BERTopic model

# %%
topic_model = BERTopic(embedding_model = "all-MiniLM-L6-v2") # English BERTopic

# %% [markdown]
# Create texts for BERTopic as: 'Заголовок' + 'Опис'

# %%
texts = preprocess_data(data)

# %% [markdown]
# Create timestamps for BERTopic as date from 'Дата'

# %%
timestamps = extract_date_days(data)

# %%
set(timestamps)
# Out:
# {'2025-02-09',
#  '2025-02-10',
#  '2025-02-11',
#  '2025-02-12',
#  '2025-02-13',
#  '2025-02-14',
#  '2025-02-15',
#  '2025-02-16'}

# %% [markdown]
# We have news only during 8 days.

# %% [markdown]
# Train model

# %%
topics, probs = topic_model.fit_transform(texts)

# %% [markdown]
# Output results

# %%
topic_model.get_topic_info().head()
# Out:
#    Topic  Count                                  Name  \
# 0     -1   2106               -1_ukraine_putin_the_to
# 1      0    323  0_zelensky_zelenskyy_volodymyr_putin
# 2      1    176   1_plant_nuclear_radiation_chernobyl
# 3      2    151   2_gabbard_tulsi_intelligence_senate
# 4      3    148                3_speech_vance_jd_free
#
#                                       Representation  \
# 0  [ukraine, putin, the, to, and, in, trump, with...
# 1  [zelensky, zelenskyy, volodymyr, putin, accept...
# 2  [plant, nuclear, radiation, chernobyl, drone, ...
# 3  [gabbard, tulsi, intelligence, senate, directo...
# 4  [speech, vance, jd, free, vice, threat, europe...
#
#                                  Representative_Docs
# 0  [Hegseth rules out NATO membership for Ukraine...
# 1  [Ukraine says it will not accept US-Russia pea...
# 2  [Ukraine says Russia drone attack hits Chernob...
# 3  [Senate confirms Gabbard as Trump's director o...
# 4  [JD Vance attacks Europe over free speech and ...

# %% [markdown]
# We have more than 2000 outliers.

# %%
topic_model.visualize_topics()

# %% [markdown]
# We have similar topics (duplicates). For example, about drone strike in Chernobyl.
#
# **Reduce the amount of topics.**

# %%
topic_model.reduce_topics(texts, nr_topics=50)

# %% [markdown]
# # Results

# %%
topic_model.get_topic_info().head()
# Out:
#    Topic  Count                               Name  \
# 0     -1   2106               -1_the_ukraine_to_in
# 1      0   2469             0_ukraine_trump_to_war
# 2      1    426  1_drones_russia_russian_ukrainian
# 3      2    391       2_fogel_marc_custody_teacher
# 4      3    314        3_gaza_aluminum_tariffs_the
#
#                                       Representation  \
# 0  [the, ukraine, to, in, and, trump, of, putin, ...
# 1  [ukraine, trump, to, war, putin, president, ru...
# 2  [drones, russia, russian, ukrainian, ukraine, ...
# 3  [fogel, marc, custody, teacher, american, rele...
# 4  [gaza, aluminum, tariffs, the, trump, is, of, ...
#
#                                  Representative_Docs
# 0  [Trump says he trusts Russia's Putin wants pea...
# 1  [Trump Says Russia Agreed To 'Immediately' Beg...
# 2  [Ukraine and Russia trade long-range attacks a...
# 3  [American School Teacher Marc Fogel Released F...
# 4  [US President Trump doubles down on plan to ta...

# %% [markdown]
# Set custom names to topics.

# %%
all_topic_ids = topic_model.get_topic_info()["Topic"].tolist()

topic_ids = [topic_id for topic_id in all_topic_ids if topic_id != -1] #exclude outliers (-1)

labels = generate_topic_labels(topic_model, topic_ids)

topic_model.set_topic_labels(labels)

# %% [markdown]
# **Plot interconnections between topics**

# %%
topic_model.visualize_topics(custom_labels=True)

# %% [markdown]
# **Topics over time**

# %% [markdown]
# **Plot the most important topics over time**

# %%
topics_over_time = topic_model.topics_over_time(texts,
                                                timestamps,
                                                nr_bins=8) # we have news during 8 days

# %%
topic_model.visualize_topics_over_time(topics_over_time,
                                       top_n_topics=5,
                                       custom_labels=True)

# %% [markdown]
# **Save results**

# %%
path_to_save = os.path.join("..", "output", "res_international.csv")

save_result_topics(topic_model, path_to_save)
