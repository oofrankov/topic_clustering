# %%
import os
import pandas as pd
from bertopic import BERTopic
from src import preprocess_data, extract_date_days, generate_topic_labels, save_result_topics

# %% [markdown]
# # Ukrainian news

# %% [markdown]
# Read data

# %%
file_path = os.path.join("..", "data.xlsx")

data = pd.read_excel(io = file_path,
                     sheet_name = "Україна")

# %% [markdown]
# **Analyze data**

# %%
data.head()
# Out:
#                   Дата                 Джерело  \
# 0  2025-02-12 09:28:50  сайт тернополя 0352.ua
# 1  2025-02-12 19:39:16               Gazeta.ua
# 2  2025-02-09 18:20:00  сайт тернополя 0352.ua
# 3  2025-02-11 14:30:00      Patriot of Ukraine
# 4  2025-02-11 16:11:00                24 Канал
#
#                                            Заголовок  \
# 0  "200 тисяч – одразу, а через рік – виїзд за ко...
# 1  "30 000 на місяць": Зеленський пояснив, наскіл...
# 2  "34 000 грн штрафу та позбавлення прав": в Укр...
# 3  "90% успіху Росії в Криму в 2014-му році - це ...
# 4  "Є приклади успішних": в ОСУВ "Хортиця" відпов...
#
#                                                 Опис  \
# 0  Про зниження мобілізаційного віку розмови трив...
# 1  Найбільша мобілізація в Україні відбулася у 20...
# 2               З'явилося попереджання для українців
# 3  Головний сержант 126 ОБр ТрО 30-го корпусу мор...
# 4  ЗСУ проводять успішні контратаки на Покровсько...
#
#                                            Посилання              Автор  \
# 0  https://www.0352.ua/news/3901613/200-tisac-odr...  Дмитро Бондаренко
# 1  https://gazeta.ua/articles/life/_30-000-na-mis...   Максимчук Леонід
# 2  https://www.0352.ua/news/3900464/34-000-grn-st...     Георгій Шевчук
# 3  https://patrioty.org.ua/politic/90-uspikhu-ros...                NaN
# 4  https://24tv.ua/kontrataki-zsu-bilya-pokrovska...        Дмитро Усик
#
#    Популярність джерела Мова Країна
# 0                116319   uk     UA
# 1                 19872   uk     UA
# 2                116319   uk     UA
# 3                234013   uk     UA
# 4                 14630   uk     UA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14577 entries, 0 to 14576
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Дата                  14577 non-null  object
#  1   Джерело               14139 non-null  object
#  2   Заголовок             14577 non-null  object
#  3   Опис                  14573 non-null  object
#  4   Посилання             14577 non-null  object
#  5   Автор                 12802 non-null  object
#  6   Популярність джерела  14577 non-null  int64
#  7   Мова                  14577 non-null  object
#  8   Країна                14577 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.0+ MB

# %% [markdown]
# We have some news without any description, but all news contain the header.

# %%
data["Мова"].value_counts()
# Out:
# Мова
# uk    14577
# Name: count, dtype: int64

# %% [markdown]
# All ukrainian news are in Ukrainian. So we have to use BERTopic that can handle Ukrainian language.

# %% [markdown]
# # Train BERTopic model

# %%
topic_model = BERTopic(embedding_model = "paraphrase-multilingual-MiniLM-L12-v2") # Multilanguage BERTopic

# %% [markdown]
# Create texts for BERTopic as: 'Заголовок' + 'Опис'

# %%
texts = preprocess_data(data)

# %% [markdown]
# Create timestamps for BERTopic as date from 'Дата'

# %%
timestamps = extract_date_days(data)

# %%
set(timestamps)
# Out:
# {'2025-02-09',
#  '2025-02-10',
#  '2025-02-11',
#  '2025-02-12',
#  '2025-02-13',
#  '2025-02-14',
#  '2025-02-15',
#  '2025-02-16'}

# %% [markdown]
# We have news only during 8 days.

# %% [markdown]
# Train model

# %%
topics, probs = topic_model.fit_transform(texts)

# %% [markdown]
# Output results

# %%
topic_model.get_topic_info().head()
# Out:
#    Topic  Count                                       Name  \
# 0     -1   4471                            -1_на_та_про_не
# 1      0    369             0_путіним_трамп_трампа_розмову
# 2      1    296                     1_збили_shahed_ппо_ніч
# 3      2    261  2_обстріляли_поранені_російські_внаслідок
# 4      3    258        3_суспільство_фото_главпост_порталі
#
#                                       Representation  \
# 0    [на, та, про, не, як, до, україни, що, рф, від]
# 1  [путіним, трамп, трампа, розмову, трампом, пут...
# 2  [збили, shahed, ппо, ніч, бпла, типу, вночі, з...
# 3  [обстріляли, поранені, російські, внаслідок, в...
# 4  [суспільство, фото, главпост, порталі, медіа, ...
#
#                                  Representative_Docs
# 0  ["Живу за часом Трампа": Келлог сказав, коли м...
# 1  [Трамп провів телефонну розмову з Путіним щодо...
# 2  [Протиповітряний бій 16 лютого: ППО збила 95 у...
# 3  [Росіяни за добу обстріляли 36 населених пункт...
# 4  [В Україні кружляють безпілотники: названо нап...

# %% [markdown]
# We have more than 4000 outliers.

# %%
topic_model.visualize_topics()

# %% [markdown]
# We have similar topics (duplicates). For example, about sanctions against Poroshenko.
#
# **Reduce the amount of topics.**

# %%
topic_model.reduce_topics(texts, nr_topics=50)

# %% [markdown]
# # Results

# %%
topic_model.get_topic_info().head()
# Out:
#    Topic  Count                            Name  \
# 0     -1   4471                 -1_на_та_про_що
# 1      0   3274                0_на_рф_та_росія
# 2      1   2128     1_сша_україни_не_зеленський
# 3      2    975         2_дронів_дрони_бпла_ніч
# 4      3    516  3_санкції_порошенка_проти_рнбо
#
#                                       Representation  \
# 0    [на, та, про, що, україни, не, до, для, за, рф]
# 1  [на, рф, та, росія, за, області, про, добу, лю...
# 2  [сша, україни, не, зеленський, що, україні, на...
# 3  [дронів, дрони, бпла, ніч, ппо, по, лютого, си...
# 4  [санкції, порошенка, проти, рнбо, суд, санкцій...
#
#                                  Representative_Docs
# 0  [Віцепрезидент США не виключає відправлення ві...
# 1  [На фронті за добу - 261 боєзіткнення, на Покр...
# 2  [Зеленський: Україна готова говорити з США про...
# 3  [Масштабна атака ворожих дронів: Україна збила...
# 4  [Forbes: РНБО запровадила санкції проти Пороше...

# %% [markdown]
# Set custom names to topics.

# %%
all_topic_ids = topic_model.get_topic_info()["Topic"].tolist()

topic_ids = [topic_id for topic_id in all_topic_ids if topic_id != -1] #exclude outliers (-1)

labels = generate_topic_labels(topic_model, topic_ids)

topic_model.set_topic_labels(labels)

# %% [markdown]
# **Plot interconnections between topics**

# %%
topic_model.visualize_topics(custom_labels=True)

# %% [markdown]
# **Topics over time**

# %% [markdown]
# **Plot the most important topics over time**

# %%
topics_over_time = topic_model.topics_over_time(texts,
                                                timestamps,
                                                nr_bins=8) # we have news during 8 days

# %%
topic_model.visualize_topics_over_time(topics_over_time,
                                       top_n_topics=5,
                                       custom_labels=True)

# %% [markdown]
# **Save results**

# %%
path_to_save = os.path.join("..", "output", "res_ukrainian.csv")

save_result_topics(topic_model, path_to_save)
